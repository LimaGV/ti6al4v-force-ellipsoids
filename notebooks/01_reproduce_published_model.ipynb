# %% [markdown]
# # Reproduce the published surface-roughness model
# This notebook fits `Ra ~ a/b + dM × (b/c)` and calculates LOOCV metrics.

# %%
from pathlib import Path
import sys
ROOT = Path.cwd().resolve()
if ROOT.name == 'notebooks':
    ROOT = ROOT.parent
sys.path.insert(0, str(ROOT / 'src'))

import pandas as pd
from machining_ellipsoids.modeling import fit_published_model, loocv_metrics

# %%
df = pd.read_csv(ROOT / 'data' / 'processed' / 'experiment_summary.csv')
df.head()

# %%
model = fit_published_model(df)
metrics, predictions = loocv_metrics(df)
model.params, model.rsquared_adj, metrics
