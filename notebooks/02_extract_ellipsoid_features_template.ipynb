# %% [markdown]
# # Template: extract covariance-ellipsoid features
# Place an experiment CSV containing `Fc`, `Ff`, and `Fp` in `data/raw/`.

# %%
from pathlib import Path
import sys
ROOT = Path.cwd().resolve()
if ROOT.name == 'notebooks':
    ROOT = ROOT.parent
sys.path.insert(0, str(ROOT / 'src'))

import pandas as pd
from machining_ellipsoids import trim_signal, compute_ellipsoid_features

# %%
# Replace with an actual raw-signal file.
signal_path = ROOT / 'data' / 'raw' / 'experiment_01.csv'
# signal = pd.read_csv(signal_path)
# signal_trimmed = trim_signal(signal, 0.10, 0.10)
# features = compute_ellipsoid_features(signal_trimmed, columns=('Fc', 'Ff', 'Fp'))
# features.as_dict()
